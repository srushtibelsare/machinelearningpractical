# %% [markdown]
# NAME:SRUSHTI BELSARE    USN NO:CS23165
#
# LAB -10
#
# Aim: To perform Hierachical clustering using agglometrive methods and interpret dendrograms for cluster formation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/ml /Mall_Customers.csv"
df=pd.read_csv(path)
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X=df[['Annual Income (k$)','Spending Score (1-100)']]

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
plt.figure(figsize=(10,5))
dendrogram(linkage(X_scaled,method='ward'))

plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean Distance')
plt.show()

# %%
hc= AgglomerativeClustering(n_clusters=5,linkage='ward')
y_hc=hc.fit_predict(X_scaled )

# %%
df['Cluster']=y_hc
print(df.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        4
# 1        3
# 2        4
# 3        3
# 4        4

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', data=df, palette='Set1')
plt.title("Hierarchical clustering of Mall Customers")
plt.show()
